# %%
df = spark.table("workspace.default.movies")
display(df)

# %%
df.show(5)

# %%
# df.printSchema()
# df.count()
# df.describe().show()
df.describe('revenue').show()

# %%
df.columns

# %%
display(df.describe())

# %%
display(df.summary())
