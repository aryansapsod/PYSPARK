-- %%
-- create table orders 
-- (
--   order_id int, 
--   order_date date,
--   customer_id int,
--   order_status string
-- );
-- insert into orders values (1,'2017-01-01',1,'PENDING'),
--   (2,'2017-02-01',2,'COMPLETE'),
--   (3,'2017-03-01',3,'PENDING'),
--   (4,'2017-04-01',2,'PENDING')

select * from orders;
